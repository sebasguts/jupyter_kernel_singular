# %%
ring r;

# %%
r;
# Out:
# //   characteristic : 32003
# //   number of vars : 3
# //        block   1 : ordering dp
# //                  : names    x y z
# //        block   2 : ordering C

# %%
ideal I = (xy,x^2);

# %%
std(I);
# Out:
# _[1]=xy
# _[2]=x2
